# %% [markdown]
# <a href="https://colab.research.google.com/github/emilymacris/ds2002-dp2/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/emilymacris/ds2002-dp2.git
# Out:
# Cloning into 'ds2002-dp2'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 176 (delta 27), reused 12 (delta 12), pack-reused 145 (from 1)
# Receiving objects: 100% (176/176), 159.10 KiB | 4.68 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
print('hello world')
# Out:
# hello world
